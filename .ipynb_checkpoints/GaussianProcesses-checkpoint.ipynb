# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, ConstantKernel as C

import GPy

# %%
def plot_with_sigma(x_train, y_train, x, y, sigma, label):
    pyplot.plot(x, y, label=label)
    pyplot.fill_between(x.ravel(), y.ravel() - 2 * sigma.ravel(), y.ravel() + 2 * sigma.ravel(), alpha=0.2)
    pyplot.plot(x_train, y_train, 'om', markersize=8, label='Data')
    pyplot.legend()

# %% [markdown]
# # GPy
#
# * Special library for GP
# * Large number of various covariance functions
# * Various GP models for large data sets
# * Simple to use

# %%
import GPy
N = 50
noise_var = 0.05

np.random.seed(1)
x_train = np.linspace(0,10,50)[:,None]
k = GPy.kern.RBF(1)
y_train = np.random.multivariate_normal(np.zeros(N), k.K(x_train) + np.eye(N) * np.sqrt(noise_var)).reshape(-1,1)

# %%
import GPy

kernel = GPy.kern.RBF(input_dim=1, variance=1., lengthscale=0.1)
model = GPy.models.GPRegression(x_train, y_train, kernel)
model.optimize()
model.plot()
# Out:
#  /home/yermek/.local/lib/python2.7/site-packages/matplotlib/figure.py:1742: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.

# %%
# kernel combinations
k1 = GPy.kern.RBF(1,1.,2.)
k2 = GPy.kern.Matern32(1, 0.5, 0.2)

# Product of kernels
k_prod = k1 * k2
k_prod.plot()

k1 = GPy.kern.RBF(1, 1., 2., active_dims=[0])
k2 = GPy.kern.Matern32(1, 0.5, 0.2, active_dims=[1])
k_prod_tensor = k1 * k2
k_prod_tensor.plot()

# %% [markdown]
# # GPflow
#
# * GPy, but with TensorFlow
# * Has all the abilities GPy
# * Simple to use
# * Bad documentation

# %%
import GPflow

kernel = GPflow.kernels.RBF(input_dim=1, variance=1., lengthscales=0.1)
model = GPflow.gpr.GPR(x_train, y_train, kern=kernel)
model.optimize()

x = np.linspace(0, 10, 100).reshape(-1, 1)
y, sigma = model.predict_y(x)
pyplot.figure()
plot_with_sigma(x_train, y_train, x, y, np.sqrt(sigma), 'GPflow')
pyplot.show()

# %% [markdown]
# # PyMC3

# %%
import pymc3 as pm
import theano.tensor as tt

# define kernel
cov = pm.gp.cov.ExpQuad(1, 0.3)
K = cov(x_train)
K_s = cov(x_train, x)
K_noise = K + 0.05 * np.eye(N) + 1e-12 * np.eye(N)

with pm.Model() as model:
    # The actual distribution of f_sample doesn't matter as long as the shape is right since it's only used
    # as a dummy variable for slice sampling with the given prior
    f_sample = pm.Flat('f_sample', shape=(N, ))

    # Likelihood
    y = pm.MvNormal('y', observed=y_train, mu=f_sample, cov=0.05 * tt.eye(N), shape=N)

    # Interpolate function values using noisy covariance matrix
    L = tt.slinalg.cholesky(K_noise)
    f_pred = pm.Deterministic('f_pred', tt.dot(K_s.T, tt.slinalg.solve(L.T, tt.slinalg.solve(L, f_sample))))

    # Use elliptical slice sampling
    ess_step = pm.EllipticalSlice(vars=[f_sample], prior_cov=K_noise)
    trace = pm.sample(2000, start=model.test_point, step=[ess_step], progressbar=False, random_seed=1)

# %%
# Analytically compute posterior mean
L = np.linalg.cholesky(K_noise.eval())
alpha = np.linalg.solve(L.T, np.linalg.solve(L, y_train))
post_mean = np.dot(K_s.T.eval(), alpha)

fig, ax = pyplot.subplots()
for idx in np.random.randint(1000, 2000, 500):
    ax.plot(x, trace['f_pred'][idx],  alpha=0.02, color='navy')
ax.scatter(x_train, y_train, s=40, color='k', label='Data');
ax.plot(x, post_mean, color='g', alpha=0.8, label='Predictions');
ax.legend();

# %% [markdown]
# # Scikit-learn

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, ConstantKernel as C

kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e1)) + WhiteKernel(noise_level=0.05)
model = GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
                                 kernel=kernel)
model.fit(x_train, y_train)


x = np.linspace(0, 10, 100).reshape(-1, 1)
y, sigma = model.predict(x, return_std=True)
pyplot.figure()
plot_with_sigma(x_train, y_train, x, y, sigma, 'GP sklearn')
pyplot.show()

# %% [markdown]
# # Bayesian Optimization
#
# * Suitable for optimization of "heavy" functions (hard to compute functions)
# * Uses approximation of the objective function
# * Takes into account the error of approximation

# %%
def f(x):
    return (6 * x - 2)**2 * np.sin(12 * x - 4)  


def lower_confidence_bound(x, model, coefficient=2):
    prediction, std = model.predict(x, return_std=True)
    return prediction.ravel() - coefficient * std.ravel()

def get_new_point(model):
    x_grid = np.linspace(0, 1, 200).reshape(-1, 1)

    lcb = lower_confidence_bound(x_grid, model, 2)

    new_point_index = np.argmin(lcb)
    x_new = x_grid[new_point_index]
    lcb = lcb[new_point_index]
    return x_new, lcb


def plot(x_train, y_train, model, x_new, lcb):
    x_grid = np.linspace(0, 1, 100).reshape(-1, 1)
    y_grid = f(x_grid)

    prediction, std = model.predict(x_grid, return_std=True)
    prediction = prediction.ravel()
    std = std.ravel()

    pyplot.figure(figsize=(8, 6))
    pyplot.plot(x_train, y_train, 'or', markersize=8, label='Training set')
    pyplot.plot(x_grid, y_grid, '--b', linewidth=2, label='True function')
    pyplot.plot(x_grid, prediction, '-k', linewidth=2, label='Approximation')
    pyplot.fill_between(x_grid.ravel(), prediction - 2 * std, prediction + 2 * std, alpha=0.3)
    pyplot.plot(x_new, lcb, 'og', markersize=10, label='New point')
    pyplot.ylim([-15, 20])
    pyplot.legend(loc='best')

def optimization_step(x_train, y_train, model):
    model.fit(x_train, y_train)

    x_new, lcb = get_new_point(model)
    plot(x_train, y_train, model, x_new, lcb)
    pyplot.show()
    
    x_train = np.vstack([x_train, x_new.reshape(-1, 1)])
    y_train = np.vstack([y_train, f(x_new).reshape(-1, 1)])
    return x_train, y_train

# %% [markdown]
# # Bayesian Optimization
#
# * Suitable for optimization of "heavy" functions (hard to compute functions)
# * Uses approximation of the objective function
# * Takes into account the error of approximation# Байсовская оптимизация

# %% [markdown]
# Optimization procedure
# * Build an approximation g(x) of the objective function f(x)
# * Choose a new point - point of suggested minimum
# $$g(x) - b \sigma(x)$$
# * Calculate value of f(x) at new point
# * Update the model and go to step 2.

# %%
np.random.seed(239)

x_train = np.array([0.0, 0.58, 0.38, 0.95]).reshape(-1, 1)
y_train = f(x_train)

kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-1, 1e1))
model = GaussianProcessRegressor(kernel=kernel, normalize_y=True)
model.fit(x_train, y_train)
# Out:
# GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#              kernel=1**2 * RBF(length_scale=10), n_restarts_optimizer=0,
#              normalize_y=True, optimizer='fmin_l_bfgs_b',
#              random_state=None)

# %%
x_grid = np.linspace(0, 1, 100).reshape(-1, 1)
y_grid = f(x_grid)
prediction, std = model.predict(x_grid, return_std=True)
prediction = prediction.ravel()
std = std.ravel()
pyplot.figure(figsize=(8, 6))
pyplot.plot(x_train, y_train, 'or', markersize=8, label='Training set')
pyplot.plot(x_grid, prediction, '-k', linewidth=2, label='Approximation')
pyplot.fill_between(x_grid.ravel(), prediction - 2 * std, prediction + 2 * std, alpha=0.3)
pyplot.ylim([-15, 20])
pyplot.legend(loc='best')

# %%
x_train, y_train = optimization_step(x_train, y_train, model)

# %%
x_train, y_train = optimization_step(x_train, y_train, model)

# %%
x_train, y_train = optimization_step(x_train, y_train, model)

# %%
x_train, y_train = optimization_step(x_train, y_train, model)

# %%
x_train, y_train = optimization_step(x_train, y_train, model)

# %%
x_train, y_train = optimization_step(x_train, y_train, model)

# %% [markdown]
# # Gaussian Process Classificatoin (GPC)
#
# Here we are goint to build GPC using GaussianProcessClassifier from scikit-learn and using PyMC3

# %%
import pymc3 as pm
import theano.tensor as tt

np.random.seed(1)
n = 30
x_train = np.sort(3 * np.random.rand(n))[:, None]

# Number of points at which to interpolate
m = 100
x = np.linspace(0, 3, m)[:, None]

# Covariance kernel parameters
noise = 0.1
lengthscale = 0.3
f_scale = 1

cov = f_scale * pm.gp.cov.ExpQuad(1, lengthscale)
K = cov(x_train)
K_s = cov(x_train, x)
K_noise = K + noise * np.eye(n)

# Add very slight perturbation to the covariance matrix diagonal to improve numerical stability
K_stable = K + 1e-12 * np.eye(n)

f = np.random.multivariate_normal(mean=np.zeros(n), cov=K_stable.eval())

# Separate data into positive and negative classes
f[f > 0] = 1
f[f <= 0] = 0

# %%
fig, ax = pyplot.subplots(figsize=(14, 6));
ax.scatter(x_train, np.ma.masked_where(f == 0, f), color='b', label='Positive Observations');
ax.scatter(x_train, np.ma.masked_where(f == 1, f), color='r', label='Negative Observations');
ax.legend(loc='lower right');
ax.set_xlim(-0.1, 3.1);
ax.set_ylim(-0.2, 1.2);

# %%
with pm.Model() as model:
    # Again, f_sample is just a dummy variable
    f_sample = pm.Flat('f_sample', shape=n)
    f_transform = pm.invlogit(f_sample)

    # Binomial likelihood
    y = pm.Binomial('y', observed=f, n=np.ones(n), p=f_transform, shape=n)

    # Interpolate function values using noiseless covariance matrix
    L = tt.slinalg.cholesky(K_stable)
    f_pred = pm.Deterministic('f_pred', tt.dot(K_s.T, tt.slinalg.solve(L.T, tt.slinalg.solve(L, f_transform))))

    # Use elliptical slice sampling
    ess_step = pm.EllipticalSlice(vars=[f_sample], prior_cov=K_stable)
    trace = pm.sample(2000, start=model.test_point, step=[ess_step], progressbar=False, random_seed=1)

# %%
fig, ax = pyplot.subplots(figsize=(14, 6));
for idx in np.random.randint(1000, 2000, 500):
    ax.plot(x, trace['f_pred'][idx],  alpha=0.04, color='navy')
ax.scatter(x_train, f, s=40, color='k');
ax.set_xlim(0, 3);
ax.set_ylim(-0.1, 1.1);

# %%
kernel = GPy.kern.RBF(1, variance=1., lengthscale=0.2)

model = GPy.core.GP(X=x_train,
                    Y=f.reshape(-1, 1), 
                    kernel=kernel, 
                    inference_method=GPy.inference.latent_function_inference.Laplace(),
                    likelihood=GPy.likelihoods.Bernoulli())

# %%
model.optimize()
print model
model.plot()
# Out:
# Name : gp
# Objective : 9.78460307861
# Number of Parameters : 2
# Number of Optimization Parameters : 2
# Updates : True
# Parameters:
#   gp.              |           value  |  constraints  |  priors
#   rbf.variance     |   50.0713911817  |      +ve      |
#   rbf.lengthscale  |  0.323621013538  |      +ve      |

# %%
def branin(x):
    const = [5.1 / 4.0 / np.pi**2, 5.0 / np.pi, -6.0, 10.0 * (1.0 - 1.0 / 8.0 / np.pi), 10.0]
    y = (x[:, 1] - const[0] * x[:, 0]**2 + const[1] * x[:, 0] + const[2])**2 + const[3] * np.cos(x[:, 0]) + const[4]
    return y


def golubev(x):
    intermediate = 5 * np.exp(-4 * np.sum((x - 0.25)**2, 1)) - \
    7 * np.exp(-40 * np.sum(x**2, 1)) - \
    3 * np.exp(-10 * (x[:, 0] + 0.7)**2) + np.sum(x, 1)
    y = np.tanh(0.3 * intermediate)
    return y

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
x = np.meshgrid(np.linspace(-1, 1, 50), np.linspace(-1, 1, 50))
x_grid = np.hstack([x[0].reshape(-1, 1), x[1].reshape(-1, 1)])
y_grid = golubev(x_grid)

figure = pyplot.figure()
ax = figure.add_subplot(111, projection='3d')
ax.plot_surface(x[0], x[1], y_grid.reshape(x[0].shape), rstride=1, cstride=1, cmap=cm.jet)
pyplot.show()

# %%
x = np.meshgrid(np.linspace(-1, 1, 20), np.linspace(-1, 1, 20))
x_train = np.hstack([x[0].reshape(-1, 1), x[1].reshape(-1, 1)])
y_train = golubev(x_grid).reshape(-1, 1)

# %%
kernel = GPy.kern.RBF(input_dim=2, variance=1, lengthscale=[0.2, 0.2], ARD=True)
m = GPy.models.GPRegressionGrid(x_train, y_train, kernel)
# Out:
# (20, 20)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-b81a2ef68c96> in <module>()
#       1 kernel = GPy.kern.RBF(input_dim=2, variance=1, lengthscale=[0.2, 0.2], ARD=True)
# ----> 2 m = GPy.models.GPRegressionGrid(x_train, y_train, kernel)
#
# /home/yermek/.local/lib/python2.7/site-packages/paramz/parameterized.pyc in __call__(self, *args, **kw)
#      52         self._model_initialized_ = False
#      53         if initialize:
# ---> 54             self.initialize_parameter()
#      55         else:
#      56             import warnings
#
# /home/yermek/.local/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in initialize_parameter(self)
#     329         self._highest_parent_._connect_parameters() #logger.debug("calling parameters changed")
#     330         self._highest_parent_._connect_fixes()
# --> 331         self.trigger_update()
#     332
#     333     @property
#
# /home/yermek/.local/lib/python2.7/site-packages/paramz/core/updateable.pyc in trigger_update(self, trigger_parent)
#      77             #print "Warning: updates are off, updating the model will do nothing"
#      78             return
# ---> 79         self._trigger_params_changed(trigger_parent)
#
# /home/yermek/.local/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in _trigger_params_changed(self, trigger_parent)
#     126         """
#     127         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 128         self.notify_observers(None, None if trigger_parent else -np.inf)
#     129
#     130     def _size_transformed(self):
#
# /home/yermek/.local/lib/python2.7/site-packages/paramz/core/observable.pyc in notify_observers(self, which, min_priority)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# /home/yermek/.local/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in _parameters_changed_notification(self, me, which)
#     496         """
#     497         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 498         self.parameters_changed()
#     499     def _pass_through_notify_observers(self, me, which=None):
#     500         self.notify_observers(which=which)
#
# /home/yermek/.local/lib/python2.7/site-packages/GPy/core/gp_grid.pyc in parameters_changed(self)
#      59             this method yourself, there may be unexpected consequences.
#      60         """
# ---> 61         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.Y_metadata)
#      62         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
#      63         self.kern.update_gradients_direct(self.grad_dict['dL_dVar'], self.grad_dict['dL_dLen'])
#
# /home/yermek/.local/lib/python2.7/site-packages/GPy/inference/latent_function_inference/gaussian_grid_inference.py in inference(self, kern, X, likelihood, Y, Y_metadata)
#      77
#      78         print QTs[0].shape
# ---> 79         alpha_kron = self.kron_mvprod(QTs, Y)
#      80         V_kron = V_kron.reshape(-1, 1)
#      81         alpha_kron = alpha_kron / (V_kron + noise)
#
# /home/yermek/.local/lib/python2.7/site-packages/GPy/inference/latent_function_inference/gaussian_grid_inference.py in kron_mvprod(self, A, b)
#      42         N = np.prod(G)
#      43         for d in range(D-1, -1, -1):
# ---> 44             X = np.reshape(x, (G[d], int(np.round(N/G[d]))), order='F')
#      45             Z = np.dot(A[d], X)
#      46             Z = Z.T
#
# /usr/lib/python2.7/dist-packages/numpy/core/fromnumeric.pyc in reshape(a, newshape, order)
#     223     except AttributeError:
#     224         return _wrapit(a, 'reshape', newshape, order=order)
# --> 225     return reshape(newshape, order=order)
#     226
#     227
#
# ValueError: total size of new array must be unchanged

# %%
# %load_ext autoreload
# %autoreload 2
